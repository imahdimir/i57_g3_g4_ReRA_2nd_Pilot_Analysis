# %%
import numpy as np
import pandas as pd
from i7_hot_reload.hot_reload import hot_reload_a_module_from_cwd


b_000_env = hot_reload_a_module_from_cwd('b_000_env')

from b_000_env import Directory
from b_000_env import FilePath
from b_000_env import Constants
from b_000_env import Parameters


d = Directory()
fp = FilePath()
c = Constants()

# %% [markdown]
# # Keep only valid responses

# %%
fp.all_apps_wide_csv_250301
# Out:
# PosixPath('/Users/mmir/Library/CloudStorage/Dropbox/ReRA/RiskPreferences-OTree Online Survey 2024-Raw Data/2nd Pilot/all_apps_wide_2025-03-01.csv')

# %%
df_raw_apps_wide = pd.read_csv(fp.all_apps_wide_csv_250301)
df_raw_apps_wide
# Out:
#      participant.id_in_session participant.code  participant.label  \
# 0                            1         xjulaqnt                NaN
# 1                            2         vc2z1rqk                NaN
# 2                            3         kb6n7gdo                NaN
# 3                            4         4ehzz2gc                NaN
# 4                            5         t6jmltim                NaN
# ..                         ...              ...                ...
# 295                         46         ghn274vj                NaN
# 296                         47         eg10g7dm                NaN
# 297                         48         qwtww654                NaN
# 298                         49         a9kjg90t                NaN
# 299                         50         hu3hdn4l                NaN
#
#      participant._is_bot  participant._index_in_pages  \
# 0                      0                            1
# 1                      0                           33
# 2                      0                           33
# 3                      0                           33
# 4                      0                           33
# ..                   ...                          ...
# 295                    0                            0
# 296                    0                            0
# 297                    0                            0
# 298                    0                            0
# 299                    0                            0
#
#      participant._max_page_index participant._current_app_name  \
# 0                             33                  Introduction
# 1                             33                 EndAndPayment
# 2                             33                 EndAndPayment
# 3                             33                 EndAndPayment
# 4                             33                 EndAndPayment
# ..                           ...                           ...
# 295                           24                           NaN
# 296                           24                           NaN
# 297                           24                           NaN
# 298                           24                           NaN
# 299                           24                           NaN
#
#     participant._current_page_name participant.time_started_utc  \
# 0                     Introduction   2025-02-11 15:47:47.700346
# 1                       ThanksPage   2025-02-11 16:05:37.167970
# 2                       ThanksPage   2025-02-11 18:21:57.987464
# 3                       ThanksPage   2025-02-11 18:32:54.168255
# 4                       ThanksPage   2025-02-11 18:49:17.748246
# ..                             ...                          ...
# 295                            NaN                          NaN
# 296                            NaN                          NaN
# 297                            NaN                          NaN
# 298                            NaN                          NaN
# 299                            NaN                          NaN
#
#      participant.visited  ...  EndAndPayment.1.player.payoff  \
# 0                      1  ...                            0.0
# 1                      1  ...                            0.0
# 2                      1  ...                            0.0
# 3                      1  ...                            0.0
# 4                      1  ...                            0.0
# ..                   ...  ...                            ...
# 295                    0  ...                            0.0
# 296                    0  ...                            0.0
# 297                    0  ...                            0.0
# 298                    0  ...                            0.0
# 299                    0  ...                            0.0
#
#      EndAndPayment.1.player.PairwisePaymentPage_timestamp  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 295                                                  0
# 296                                                  0
# 297                                                  0
# 298                                                  0
# 299                                                  0
#
#      EndAndPayment.1.player.NodewisePaymentPage_timestamp  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 295                                                  0
# 296                                                  0
# 297                                                  0
# 298                                                  0
# 299                                                  0
#
#      EndAndPayment.1.player.ThanksPage_timestamp  \
# 0                                              0
# 1                                  1739290857611
# 2                                  1739299111412
# 3                                  1739299885508
# 4                                  1739301525273
# ..                                           ...
# 295                                            0
# 296                                            0
# 297                                            0
# 298                                            0
# 299                                            0
#
#     EndAndPayment.1.player.lottery EndAndPayment.1.player.final_payment  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ..                             ...                                  ...
# 295                            NaN                                  NaN
# 296                            NaN                                  NaN
# 297                            NaN                                  NaN
# 298                            NaN                                  NaN
# 299                            NaN                                  NaN
#
#     EndAndPayment.1.player.recon_choice  EndAndPayment.1.player.comment  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# ..                                  ...                             ...
# 295                                 NaN                             NaN
# 296                                 NaN                             NaN
# 297                                 NaN                             NaN
# 298                                 NaN                             NaN
# 299                                 NaN                             NaN
#
#     EndAndPayment.1.group.id_in_subsession  \
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
# ..                                     ...
# 295                                      1
# 296                                      1
# 297                                      1
# 298                                      1
# 299                                      1
#
#     EndAndPayment.1.subsession.round_number
# 0                                         1
# 1                                         1
# 2                                         1
# 3                                         1
# 4                                         1
# ..                                      ...
# 295                                       1
# 296                                       1
# 297                                       1
# 298                                       1
# 299                                       1
#
# [300 rows x 296 columns]
